# %% [markdown]
# <a href="https://colab.research.google.com/github/prince90038/corona-prediction/blob/main/Experiment512_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Covid-19 Classification Based On Chest X-Ray#

# %% [markdown]
# Mount the Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Unzip the Dataset File

# %%
from zipfile import ZipFile
file_name = "/content/drive/MyDrive/COVID-19 Radiography Database.zip"

with ZipFile(file_name,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %% [markdown]
# Importing the Libraries

# %%
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPool2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Activation
from keras.preprocessing.image import ImageDataGenerator
import time
import matplotlib.pyplot as plt
import numpy as np
from keras.preprocessing import image
import cv2
import os
import random
import shutil
from sklearn.metrics import confusion_matrix
import seaborn as sns
import itertools
from sklearn.metrics import classification_report

# %% [markdown]
# #Creating Custom Dataset#

# %%
class_names = ['normal', 'viral', 'covid']
root_dir = 'COVID-19 Radiography Database'
source_dirs = ['NORMAL', 'Viral Pneumonia', 'COVID-19']

if os.path.isdir(os.path.join(root_dir, source_dirs[1])):
    os.mkdir(os.path.join(root_dir, 'test'))
    os.mkdir(os.path.join(root_dir, 'train'))
    os.mkdir(os.path.join(root_dir,'validation'))

    for i, d in enumerate(source_dirs):
        os.rename(os.path.join(root_dir, d), os.path.join(root_dir, class_names[i]))

    for c in class_names:
        os.mkdir(os.path.join(root_dir, 'test', c))
        os.mkdir(os.path.join(root_dir, 'validation', c))

    for c in class_names:
        images = [x for x in os.listdir(os.path.join(root_dir, c)) if x.lower().endswith('png')]
        selected_images = random.sample(images, 315)
        for image in selected_images:
            source_path = os.path.join(root_dir, c, image)
            target_path = os.path.join(root_dir, 'test', c, image)
            shutil.move(source_path, target_path)
    for c in class_names:
        images = [x for x in os.listdir(os.path.join(root_dir, c)) if x.lower().endswith('png')]
        selected_images = random.sample(images, 10)
        for image in selected_images:
            source_path = os.path.join(root_dir, c, image)
            target_path = os.path.join(root_dir, 'validation', c, image)
            shutil.move(source_path, target_path)     


     
    for c in class_names:
        shutil.move(os.path.join(root_dir, c), os.path.join(root_dir, 'train'))

# %% [markdown]
# #Data Pre-processing Phase#

# %%
TrainingImagePath='/content/COVID-19 Radiography Database/train'
TestImagePath='/content/COVID-19 Radiography Database/test'
batch_size = 32

train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range = 0.1,
        zoom_range = 0.1,
        horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory(
        TrainingImagePath,
        target_size = (512, 512),
        batch_size = batch_size,
        class_mode = 'categorical')

test_set = test_datagen.flow_from_directory(
        TestImagePath,
        target_size = (512, 512),
        batch_size = batch_size,
        shuffle = False,
        class_mode = 'categorical')

test_set.class_indices
# Out:
# Found 2854 images belonging to 3 classes.
# Found 945 images belonging to 3 classes.
# {'covid': 0, 'normal': 1, 'viral': 2}

# %%
TrainClasses = training_set.class_indices

labels = {}
for faceName, faceValue in TrainClasses.items():
    labels[faceValue] = faceName

print('Mapping of Dataset\n')
for key, value in labels.items():
    print(str(key) + " --> " + value)

OutputNeurons = len(labels)
print('\nRequired Output Neurons:{}'.format(OutputNeurons))
# Out:
# Mapping of Dataset
#
# 0 --> covid
# 1 --> normal
# 2 --> viral
#
# Required Output Neurons:3

# %% [markdown]
# #CNN Model#

# %% [markdown]
# Initializing the Convolutional Neural Network

# %%
cnn = Sequential()

# %% [markdown]
# #Step:1#
#
# #Convolution#

# %% [markdown]
# Adding the first layer of CNN

# %%
cnn.add(Convolution2D(32, kernel_size=(5, 5), strides=(1, 1), input_shape=(512,512,3), activation='relu'))

# %% [markdown]
# #Step:2#
# #MAX Pooling#

# %%
cnn.add(MaxPool2D(pool_size=(2,2)))

# %% [markdown]
# #Addtional Layer of Convulution#

# %%
cnn.add(Convolution2D(64, kernel_size=(5, 5), strides=(1, 1), activation='relu'))
cnn.add(MaxPool2D(pool_size=(2,2)))

# %%
cnn.add(Convolution2D(128, kernel_size=(5, 5), strides=(1, 1), activation='relu'))
cnn.add(MaxPool2D(pool_size=(2,2)))

# %%
cnn.add(Convolution2D(512, kernel_size=(5, 5), strides=(1, 1), activation='relu'))
cnn.add(MaxPool2D(pool_size=(2,2)))

# %% [markdown]
# #Step:3#
# #Flattening#

# %%
cnn.add(Flatten())

# %% [markdown]
# #Step:4#
# #Fully Connected Neural Network#

# %%
cnn.add(Dense(150, activation='relu'))
cnn.add(Dropout(0.3))
cnn.add(Dense(75, activation='relu'))
cnn.add(Dropout(0.3))
# cnn.add(Dense(200, activation='relu'))
# cnn.add(Dropout(0.3))
# cnn.add(Dense(100, activation='relu'))
# cnn.add(Dropout(0.3))
# cnn.add(Dense(50, activation='relu'))
# cnn.add(Dropout(0.3))
cnn.add(Dense(OutputNeurons, activation='softmax'))

# %% [markdown]
# #Compiling the CNN#

# %%
cnn.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=["accuracy"])

# %% [markdown]
# #Start Training the Model#

# %%
StartTime=time.time()
classifier = cnn.fit(
                    training_set,
                    # steps_per_epoch=160,
                    epochs=50,
                    validation_data=test_set,
                    validation_steps=(765//batch_size))

EndTime = time.time()
print()
print("*"*137)
print('Total Time Taken to Train the Model: ', round((EndTime-StartTime)/60), 'Minutes')
# Out:
# Epoch 1/50
# 90/90 [==============================] - 285s 3s/step - loss: 1.2379 - accuracy: 0.5063 - val_loss: 0.2731 - val_accuracy: 0.9049
# Epoch 2/50
# 90/90 [==============================] - 227s 3s/step - loss: 0.4231 - accuracy: 0.8533 - val_loss: 0.1497 - val_accuracy: 0.9429
# Epoch 3/50
# 90/90 [==============================] - 228s 3s/step - loss: 1.4914 - accuracy: 0.7038 - val_loss: 0.2679 - val_accuracy: 0.9022
# Epoch 4/50
# 90/90 [==============================] - 228s 3s/step - loss: 0.4375 - accuracy: 0.8391 - val_loss: 0.2274 - val_accuracy: 0.9266
# Epoch 5/50
# 90/90 [==============================] - 228s 3s/step - loss: 0.3941 - accuracy: 0.8647 - val_loss: 0.2258 - val_accuracy: 0.9117
# Epoch 6/50
# 90/90 [==============================] - 229s 3s/step - loss: 0.2982 - accuracy: 0.8983 - val_loss: 0.2426 - val_accuracy: 0.9307
# Epoch 7/50
# 90/90 [==============================] - 228s 3s/step - loss: 0.2994 - accuracy: 0.8988 - val_loss: 0.1692 - val_accuracy: 0.9579
# Epoch 8/50
# 90/90 [==============================] - 227s 3s/step - loss: 0.2815 - accuracy: 0.9094 - val_loss: 0.1598 - val_accuracy: 0.9497
# Epoch 9/50
# 90/90 [==============================] - 228s 3s/step - loss: 0.2365 - accuracy: 0.9208 - val_loss: 0.1880 - val_accuracy: 0.9443
# Epoch 10/50
# 90/90 [==============================] - 224s 2s/step - loss: 0.2240 - accuracy: 0.9239 - val_loss: 0.1709 - val_accuracy: 0.9457
# Epoch 11/50
# 90/90 [==============================] - 224s 2s/step - loss: 0.2492 - accuracy: 0.9171 - val_loss: 0.1337 - val_accuracy: 0.9592
# Epoch 12/50
# 90/90 [==============================] - 224s 2s/step - loss: 0.2350 - accuracy: 0.9199 - val_loss: 0.1345 - val_accuracy: 0.9647
# Epoch 13/50
# 90/90 [==============================] - 227s 3s/step - loss: 0.2204 - accuracy: 0.9254 - val_loss: 0.1565 - val_accuracy: 0.9606
# Epoch 14/50
# 90/90 [==============================] - 225s 2s/step - loss: 0.2206 - accuracy: 0.9228 - val_loss: 0.1566 - val_accuracy: 0.9443
# Epoch 15/50
# 90/90 [==============================] - 225s 2s/step - loss: 0.2466 - accuracy: 0.9241 - val_loss: 0.1145 - val_accuracy: 0.9647
# Epoch 16/50
# 90/90 [==============================] - 224s 2s/step - loss: 0.2486 - accuracy: 0.9235 - val_loss: 0.1395 - val_accuracy: 0.9606
# Epoch 17/50
# 90/90 [==============================] - 225s 2s/step - loss: 0.2067 - accuracy: 0.9253 - val_loss: 0.1430 - val_accuracy: 0.9620
# Epoch 18/50
# 90/90 [==============================] - 225s 2s/step - loss: 0.2074 - accuracy: 0.9302 - val_loss: 0.1342 - val_accuracy: 0.9688
# Epoch 19/50
# 90/90 [==============================] - 223s 2s/step - loss: 0.1816 - accuracy: 0.9373 - val_loss: 0.1823 - val_accuracy: 0.9538
# Epoch 20/50
# 90/90 [==============================] - 219s 2s/step - loss: 0.2032 - accuracy: 0.9305 - val_loss: 0.1388 - val_accuracy: 0.9633
# Epoch 21/50
# 90/90 [==============================] - 219s 2s/step - loss: 0.1901 - accuracy: 0.9303 - val_loss: 0.1265 - val_accuracy: 0.9674
# Epoch 22/50
# 90/90 [==============================] - 223s 2s/step - loss: 0.1694 - accuracy: 0.9446 - val_loss: 0.1477 - val_accuracy: 0.9633
# Epoch 23/50
# 90/90 [==============================] - 215s 2s/step - loss: 0.1974 - accuracy: 0.9363 - val_loss: 0.1256 - val_accuracy: 0.9647
# Epoch 24/50
# 90/90 [==============================] - 211s 2s/step - loss: 0.1725 - accuracy: 0.9400 - val_loss: 0.1338 - val_accuracy: 0.9633
# Epoch 25/50
# 90/90 [==============================] - 215s 2s/step - loss: 0.1959 - accuracy: 0.9336 - val_loss: 0.1312 - val_accuracy: 0.9674
# Epoch 26/50
# 90/90 [==============================] - 211s 2s/step - loss: 0.1587 - accuracy: 0.9447 - val_loss: 0.1590 - val_accuracy: 0.9524
# Epoch 27/50
# 90/90 [==============================] - 209s 2s/step - loss: 0.1908 - accuracy: 0.9380 - val_loss: 0.1519 - val_accuracy: 0.9688
# Epoch 28/50
# 90/90 [==============================] - 209s 2s/step - loss: 0.1633 - accuracy: 0.9360 - val_loss: 0.1357 - val_accuracy: 0.9647
# Epoch 29/50
# 90/90 [==============================] - 215s 2s/step - loss: 0.1553 - accuracy: 0.9454 - val_loss: 0.1308 - val_accuracy: 0.9688
# Epoch 30/50
# 90/90 [==============================] - 214s 2s/step - loss: 0.1431 - accuracy: 0.9538 - val_loss: 0.1147 - val_accuracy: 0.9674
# Epoch 31/50
# 90/90 [==============================] - 216s 2s/step - loss: 0.1597 - accuracy: 0.9443 - val_loss: 0.1211 - val_accuracy: 0.9688
# Epoch 32/50
# 90/90 [==============================] - 217s 2s/step - loss: 0.1189 - accuracy: 0.9586 - val_loss: 0.1451 - val_accuracy: 0.9688
# Epoch 33/50
# 90/90 [==============================] - 226s 3s/step - loss: 0.1240 - accuracy: 0.9534 - val_loss: 0.2328 - val_accuracy: 0.9484
# Epoch 34/50
# 90/90 [==============================] - 211s 2s/step - loss: 0.1241 - accuracy: 0.9574 - val_loss: 0.1234 - val_accuracy: 0.9701
# Epoch 35/50
# 90/90 [==============================] - 210s 2s/step - loss: 0.1349 - accuracy: 0.9565 - val_loss: 0.1221 - val_accuracy: 0.9633
# Epoch 36/50
# 90/90 [==============================] - 209s 2s/step - loss: 0.1405 - accuracy: 0.9516 - val_loss: 0.1808 - val_accuracy: 0.9620
# Epoch 37/50
# 90/90 [==============================] - 209s 2s/step - loss: 0.1210 - accuracy: 0.9573 - val_loss: 0.1239 - val_accuracy: 0.9688
# Epoch 38/50
# 90/90 [==============================] - 207s 2s/step - loss: 0.1449 - accuracy: 0.9536 - val_loss: 0.1600 - val_accuracy: 0.9620
# Epoch 39/50
# 90/90 [==============================] - 209s 2s/step - loss: 0.1244 - accuracy: 0.9539 - val_loss: 0.1104 - val_accuracy: 0.9620
# Epoch 40/50
# 90/90 [==============================] - 209s 2s/step - loss: 0.1161 - accuracy: 0.9579 - val_loss: 0.1355 - val_accuracy: 0.9674
# Epoch 41/50
# 90/90 [==============================] - 204s 2s/step - loss: 0.1211 - accuracy: 0.9582 - val_loss: 0.1289 - val_accuracy: 0.9633
# Epoch 42/50
# 90/90 [==============================] - 204s 2s/step - loss: 0.0975 - accuracy: 0.9657 - val_loss: 0.1742 - val_accuracy: 0.9497
# Epoch 43/50
# 90/90 [==============================] - 202s 2s/step - loss: 0.1133 - accuracy: 0.9505 - val_loss: 0.1005 - val_accuracy: 0.9688
# Epoch 44/50
# 90/90 [==============================] - 201s 2s/step - loss: 0.1551 - accuracy: 0.9471 - val_loss: 0.0961 - val_accuracy: 0.9701
# Epoch 45/50
# 90/90 [==============================] - 200s 2s/step - loss: 0.1080 - accuracy: 0.9644 - val_loss: 0.0921 - val_accuracy: 0.9742
# Epoch 46/50
# 90/90 [==============================] - 199s 2s/step - loss: 0.0975 - accuracy: 0.9624 - val_loss: 0.1377 - val_accuracy: 0.9660
# Epoch 47/50
# 90/90 [==============================] - 200s 2s/step - loss: 0.1039 - accuracy: 0.9640 - val_loss: 0.1506 - val_accuracy: 0.9620
# Epoch 48/50
# 90/90 [==============================] - 200s 2s/step - loss: 0.1148 - accuracy: 0.9537 - val_loss: 0.0943 - val_accuracy: 0.9742
# Epoch 49/50
# 90/90 [==============================] - 200s 2s/step - loss: 0.1126 - accuracy: 0.9623 - val_loss: 0.0814 - val_accuracy: 0.9728
# Epoch 50/50
# 90/90 [==============================] - 201s 2s/step - loss: 0.1156 - accuracy: 0.9593 - val_loss: 0.1764 - val_accuracy: 0.9660
#
# *****************************************************************************************************************************************
# Total Time Taken to Train the Model:  182 Minutes

# %% [markdown]
# #Training and Validation Accuracy Graph#

# %%
acc = classifier.history['accuracy']
val_acc = classifier.history['val_accuracy']
loss = classifier.history['loss']
val_loss = classifier.history['val_loss']
epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.ylabel('accuracy') 
plt.xlabel('epoch')
plt.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# #Training and Validation Loss Graph#

# %%
acc = classifier.history['accuracy']
val_acc = classifier.history['val_accuracy']
loss = classifier.history['loss']
val_loss = classifier.history['val_loss']
epochs = range(len(acc))

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.ylabel('loss') 
plt.xlabel('epoch')
plt.legend()
plt.show()

# %% [markdown]
# #Final Prediction#

# %%
fig = plt.figure(figsize=(18, 10))

rows = 1
columns = 3

fig.add_subplot(rows, columns, 1)
ImagePath = '/content/COVID-19 Radiography Database/validation/covid/COVID-19 (109).png'
Image = cv2.imread(ImagePath)
test_image = image.load_img(ImagePath,target_size=(512, 512))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image,axis=0)
result = cnn.predict(test_image)

plt.imshow(Image)
col = 'green' if labels[0] == labels[np.argmax(result)] else 'red'
plt.xlabel(labels[0])
plt.ylabel(labels[np.argmax(result)], color=col)

fig.add_subplot(rows, columns, 2)

ImagePath = '/content/COVID-19 Radiography Database/validation/normal/NORMAL (1179).png'
test_image = image.load_img(ImagePath,target_size=(512, 512))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image,axis=0)
result = cnn.predict(test_image)
Image = cv2.imread(ImagePath)

plt.imshow(Image)
col = 'green' if labels[1] == labels[np.argmax(result)] else 'red'
plt.xlabel(labels[1])
plt.ylabel(labels[np.argmax(result)], color=col)

fig.add_subplot(rows, columns, 3)
ImagePath = '/content/COVID-19 Radiography Database/validation/viral/Viral Pneumonia (340).png'
Image = cv2.imread(ImagePath)
test_image = image.load_img(ImagePath,target_size=(512, 512))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image,axis=0)
result = cnn.predict(test_image)

plt.imshow(Image)
col = 'green' if labels[2] == labels[np.argmax(result)] else 'red'
plt.xlabel(labels[2])
plt.ylabel(labels[np.argmax(result)], color=col)
# Out:
# Text(0, 0.5, 'viral')

# %% [markdown]
# ##Confusion Matrix##

# %%
def plot_confusion_matrix(cm, classes, normalize = True, title = 'Confusion matrix', cmap = plt.cm.Reds):
    plt.figure(figsize = (10,6))
    plt.imshow(cm, interpolation = 'nearest', cmap = cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 45, fontsize = 10)
    plt.yticks(tick_marks, classes, fontsize = 10)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis = 1)[:, np.newaxis]
        cm = np.around(cm, decimals = 2)
        cm[np.isnan(cm)] = 0.0
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment = "center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True Label', fontsize = 13)
    plt.xlabel('Predicted Label', fontsize = 13)

# %%
target_names = ['covid', 'normal', 'viral']

Y_pred = cnn.predict(test_set)
y_pred = np.argmax(Y_pred, axis=1)

# %%
print('Confusion Matrix')
cm = confusion_matrix(test_set.classes, y_pred)
plot_confusion_matrix(cm, target_names, title = 'Confusion Matrix')
# Out:
# Confusion Matrix
# Normalized confusion matrix

# %%
print('                      Classification Report')
print()
print(classification_report(test_set.classes, y_pred, target_names = target_names))
# Out:
#                       Classification Report
#
#               precision    recall  f1-score   support
#
#        covid       1.00      0.97      0.98       315
#       normal       0.91      0.98      0.94       315
#        viral       0.96      0.91      0.94       315
#
#     accuracy                           0.95       945
#    macro avg       0.96      0.95      0.95       945
# weighted avg       0.96      0.95      0.95       945
