# %% [markdown]
# <a href="https://colab.research.google.com/github/prince90038/corona-prediction/blob/main/Experiment512_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Covid-19 Classification Based On Chest X-Ray#

# %% [markdown]
# Mount the Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Unzip the Dataset File

# %%
from zipfile import ZipFile
file_name = "/content/drive/MyDrive/COVID-19 Radiography Database.zip"

with ZipFile(file_name,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %% [markdown]
# Importing the Libraries

# %%
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPool2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Activation
from keras.preprocessing.image import ImageDataGenerator
import time
import matplotlib.pyplot as plt
import numpy as np
from keras.preprocessing import image
import cv2
import os
import random
import shutil
from sklearn.metrics import confusion_matrix
import seaborn as sns
import itertools
from sklearn.metrics import classification_report

# %% [markdown]
# #Creating Custom Dataset#

# %%
class_names = ['normal', 'viral', 'covid']
root_dir = 'COVID-19 Radiography Database'
source_dirs = ['NORMAL', 'Viral Pneumonia', 'COVID-19']

if os.path.isdir(os.path.join(root_dir, source_dirs[1])):
    os.mkdir(os.path.join(root_dir, 'test'))
    os.mkdir(os.path.join(root_dir, 'train'))
    os.mkdir(os.path.join(root_dir,'validation'))

    for i, d in enumerate(source_dirs):
        os.rename(os.path.join(root_dir, d), os.path.join(root_dir, class_names[i]))

    for c in class_names:
        os.mkdir(os.path.join(root_dir, 'test', c))
        os.mkdir(os.path.join(root_dir, 'validation', c))

    for c in class_names:
        images = [x for x in os.listdir(os.path.join(root_dir, c)) if x.lower().endswith('png')]
        selected_images = random.sample(images, 315)
        for image in selected_images:
            source_path = os.path.join(root_dir, c, image)
            target_path = os.path.join(root_dir, 'test', c, image)
            shutil.move(source_path, target_path)
    for c in class_names:
        images = [x for x in os.listdir(os.path.join(root_dir, c)) if x.lower().endswith('png')]
        selected_images = random.sample(images, 10)
        for image in selected_images:
            source_path = os.path.join(root_dir, c, image)
            target_path = os.path.join(root_dir, 'validation', c, image)
            shutil.move(source_path, target_path)     


     
    for c in class_names:
        shutil.move(os.path.join(root_dir, c), os.path.join(root_dir, 'train'))

# %% [markdown]
# #Data Pre-processing Phase#

# %%
TrainingImagePath='/content/COVID-19 Radiography Database/train'
TestImagePath='/content/COVID-19 Radiography Database/test'
batch_size = 32

train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range = 0.1,
        zoom_range = 0.1,
        horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory(
        TrainingImagePath,
        target_size = (512, 512),
        batch_size = batch_size,
        class_mode = 'categorical')

test_set = test_datagen.flow_from_directory(
        TestImagePath,
        target_size = (512, 512),
        batch_size = batch_size,
        shuffle = False,
        class_mode = 'categorical')

test_set.class_indices
# Out:
# Found 2854 images belonging to 3 classes.
# Found 945 images belonging to 3 classes.
# {'covid': 0, 'normal': 1, 'viral': 2}

# %%
TrainClasses = training_set.class_indices

labels = {}
for faceName, faceValue in TrainClasses.items():
    labels[faceValue] = faceName

print('Mapping of Dataset\n')
for key, value in labels.items():
    print(str(key) + " --> " + value)

OutputNeurons = len(labels)
print('\nRequired Output Neurons:{}'.format(OutputNeurons))
# Out:
# Mapping of Dataset
#
# 0 --> covid
# 1 --> normal
# 2 --> viral
#
# Required Output Neurons:3

# %% [markdown]
# #CNN Model#

# %% [markdown]
# Initializing the Convolutional Neural Network

# %%
cnn = Sequential()

# %% [markdown]
# #Step:1#
#
# #Convolution#

# %% [markdown]
# Adding the first layer of CNN

# %%
cnn.add(Convolution2D(32, kernel_size=(5, 5), strides=(1, 1), input_shape=(512,512,3), activation='relu'))

# %% [markdown]
# #Step:2#
# #MAX Pooling#

# %%
cnn.add(MaxPool2D(pool_size=(2,2)))

# %% [markdown]
# #Addtional Layer of Convulution#

# %%
cnn.add(Convolution2D(64, kernel_size=(5, 5), strides=(1, 1), activation='relu'))
cnn.add(MaxPool2D(pool_size=(2,2)))

# %%
cnn.add(Convolution2D(128, kernel_size=(5, 5), strides=(1, 1), activation='relu'))
cnn.add(MaxPool2D(pool_size=(2,2)))

# %%
cnn.add(Convolution2D(256, kernel_size=(5, 5), strides=(1, 1), activation='relu'))
cnn.add(MaxPool2D(pool_size=(2,2)))

# %%
cnn.add(Convolution2D(512, kernel_size=(5, 5), strides=(1, 1), activation='relu'))
cnn.add(MaxPool2D(pool_size=(2,2)))

# %%
cnn.add(Convolution2D(1024, kernel_size=(5, 5), strides=(1, 1), activation='relu'))
cnn.add(MaxPool2D(pool_size=(2,2)))

# %% [markdown]
# #Step:3#
# #Flattening#

# %%
cnn.add(Flatten())

# %% [markdown]
# #Step:4#
# #Fully Connected Neural Network#

# %%
cnn.add(Dense(200, activation='relu'))
cnn.add(Dropout(0.3))
cnn.add(Dense(100, activation='relu'))
cnn.add(Dropout(0.3))
cnn.add(Dense(50, activation='relu'))
cnn.add(Dropout(0.3))
cnn.add(Dense(OutputNeurons, activation='softmax'))

# %% [markdown]
# #Compiling the CNN#

# %%
cnn.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=["accuracy"])

# %% [markdown]
# #Start Training the Model#

# %%
StartTime=time.time()
classifier = cnn.fit(
                    training_set,
                    # steps_per_epoch=160,
                    epochs=50,
                    validation_data=test_set,
                    validation_steps=(765//batch_size))

EndTime = time.time()
print()
print("*"*137)
print('Total Time Taken to Train the Model: ', round((EndTime-StartTime)/60), 'Minutes')
# Out:
# Epoch 1/50
# 90/90 [==============================] - 231s 2s/step - loss: 1.2065 - accuracy: 0.3431 - val_loss: 1.1065 - val_accuracy: 0.4280
# Epoch 2/50
# 90/90 [==============================] - 178s 2s/step - loss: 1.0947 - accuracy: 0.3546 - val_loss: 1.1177 - val_accuracy: 0.4280
# Epoch 3/50
# 90/90 [==============================] - 178s 2s/step - loss: 1.0939 - accuracy: 0.3507 - val_loss: 1.1229 - val_accuracy: 0.4280
# Epoch 4/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0918 - accuracy: 0.3738 - val_loss: 1.1218 - val_accuracy: 0.4280
# Epoch 5/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0926 - accuracy: 0.3875 - val_loss: 1.1250 - val_accuracy: 0.1440
# Epoch 6/50
# 90/90 [==============================] - 176s 2s/step - loss: 1.0930 - accuracy: 0.3567 - val_loss: 1.1234 - val_accuracy: 0.1440
# Epoch 7/50
# 90/90 [==============================] - 176s 2s/step - loss: 1.0954 - accuracy: 0.3542 - val_loss: 1.1239 - val_accuracy: 0.1440
# Epoch 8/50
# 90/90 [==============================] - 176s 2s/step - loss: 1.0927 - accuracy: 0.3508 - val_loss: 1.1258 - val_accuracy: 0.1440
# Epoch 9/50
# 90/90 [==============================] - 176s 2s/step - loss: 1.0920 - accuracy: 0.3504 - val_loss: 1.1263 - val_accuracy: 0.1440
# Epoch 10/50
# 90/90 [==============================] - 178s 2s/step - loss: 1.0946 - accuracy: 0.3548 - val_loss: 1.1255 - val_accuracy: 0.1440
# Epoch 11/50
# 90/90 [==============================] - 176s 2s/step - loss: 1.0927 - accuracy: 0.3627 - val_loss: 1.1248 - val_accuracy: 0.1440
# Epoch 12/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0959 - accuracy: 0.3799 - val_loss: 1.1246 - val_accuracy: 0.1440
# Epoch 13/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0933 - accuracy: 0.3588 - val_loss: 1.1244 - val_accuracy: 0.1440
# Epoch 14/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0926 - accuracy: 0.3657 - val_loss: 1.1249 - val_accuracy: 0.4280
# Epoch 15/50
# 90/90 [==============================] - 176s 2s/step - loss: 1.0932 - accuracy: 0.3446 - val_loss: 1.1269 - val_accuracy: 0.1440
# Epoch 16/50
# 90/90 [==============================] - 176s 2s/step - loss: 1.0958 - accuracy: 0.3431 - val_loss: 1.1250 - val_accuracy: 0.1440
# Epoch 17/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0948 - accuracy: 0.3527 - val_loss: 1.1227 - val_accuracy: 0.4280
# Epoch 18/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0956 - accuracy: 0.3336 - val_loss: 1.1269 - val_accuracy: 0.1440
# Epoch 19/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0938 - accuracy: 0.3482 - val_loss: 1.1292 - val_accuracy: 0.1440
# Epoch 20/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0963 - accuracy: 0.3435 - val_loss: 1.1252 - val_accuracy: 0.1440
# Epoch 21/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0899 - accuracy: 0.3694 - val_loss: 1.1239 - val_accuracy: 0.1440
# Epoch 22/50
# 90/90 [==============================] - 178s 2s/step - loss: 1.0940 - accuracy: 0.3328 - val_loss: 1.1241 - val_accuracy: 0.1440
# Epoch 23/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0951 - accuracy: 0.3508 - val_loss: 1.1238 - val_accuracy: 0.4280
# Epoch 24/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0931 - accuracy: 0.3566 - val_loss: 1.1236 - val_accuracy: 0.4280
# Epoch 25/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0948 - accuracy: 0.3545 - val_loss: 1.1249 - val_accuracy: 0.1440
# Epoch 26/50
# 90/90 [==============================] - 178s 2s/step - loss: 1.0950 - accuracy: 0.3554 - val_loss: 1.1256 - val_accuracy: 0.1440
# Epoch 27/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0916 - accuracy: 0.3661 - val_loss: 1.1247 - val_accuracy: 0.1440
# Epoch 28/50
# 90/90 [==============================] - 176s 2s/step - loss: 1.0940 - accuracy: 0.3573 - val_loss: 1.1247 - val_accuracy: 0.1440
# Epoch 29/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0927 - accuracy: 0.3740 - val_loss: 1.1236 - val_accuracy: 0.4280
# Epoch 30/50
# 90/90 [==============================] - 176s 2s/step - loss: 1.0919 - accuracy: 0.3652 - val_loss: 1.1214 - val_accuracy: 0.4280
# Epoch 31/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0932 - accuracy: 0.3473 - val_loss: 1.1231 - val_accuracy: 0.1440
# Epoch 32/50
# 90/90 [==============================] - 178s 2s/step - loss: 1.0926 - accuracy: 0.3647 - val_loss: 1.1224 - val_accuracy: 0.1440
# Epoch 33/50
# 90/90 [==============================] - 178s 2s/step - loss: 1.0952 - accuracy: 0.3557 - val_loss: 1.1259 - val_accuracy: 0.1440
# Epoch 34/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0941 - accuracy: 0.3572 - val_loss: 1.1262 - val_accuracy: 0.1440
# Epoch 35/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0961 - accuracy: 0.3554 - val_loss: 1.1266 - val_accuracy: 0.4280
# Epoch 36/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0947 - accuracy: 0.3490 - val_loss: 1.1237 - val_accuracy: 0.4280
# Epoch 37/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0982 - accuracy: 0.3428 - val_loss: 1.1247 - val_accuracy: 0.4280
# Epoch 38/50
# 90/90 [==============================] - 178s 2s/step - loss: 1.0960 - accuracy: 0.3614 - val_loss: 1.1270 - val_accuracy: 0.1440
# Epoch 39/50
# 90/90 [==============================] - 176s 2s/step - loss: 1.0919 - accuracy: 0.3478 - val_loss: 1.1255 - val_accuracy: 0.1440
# Epoch 40/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0953 - accuracy: 0.3509 - val_loss: 1.1266 - val_accuracy: 0.1440
# Epoch 41/50
# 90/90 [==============================] - 178s 2s/step - loss: 1.0922 - accuracy: 0.3516 - val_loss: 1.1268 - val_accuracy: 0.1440
# Epoch 42/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0931 - accuracy: 0.3441 - val_loss: 1.1267 - val_accuracy: 0.1440
# Epoch 43/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0938 - accuracy: 0.3458 - val_loss: 1.1280 - val_accuracy: 0.1440
# Epoch 44/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0931 - accuracy: 0.3704 - val_loss: 1.1262 - val_accuracy: 0.1440
# Epoch 45/50
# 90/90 [==============================] - 178s 2s/step - loss: 1.0941 - accuracy: 0.3518 - val_loss: 1.1252 - val_accuracy: 0.1440
# Epoch 46/50
# 90/90 [==============================] - 178s 2s/step - loss: 1.0936 - accuracy: 0.3541 - val_loss: 1.1268 - val_accuracy: 0.1440
# Epoch 47/50
# 90/90 [==============================] - 178s 2s/step - loss: 1.0921 - accuracy: 0.3692 - val_loss: 1.1244 - val_accuracy: 0.1440
# Epoch 48/50
# 90/90 [==============================] - 177s 2s/step - loss: 1.0920 - accuracy: 0.3736 - val_loss: 1.1236 - val_accuracy: 0.1440
# Epoch 49/50
# 90/90 [==============================] - 178s 2s/step - loss: 1.0935 - accuracy: 0.3668 - val_loss: 1.1237 - val_accuracy: 0.1440
# Epoch 50/50
# 90/90 [==============================] - 178s 2s/step - loss: 1.0947 - accuracy: 0.3396 - val_loss: 1.1245 - val_accuracy: 0.1440
#
# *****************************************************************************************************************************************
# Total Time Taken to Train the Model:  149 Minutes

# %% [markdown]
# #Training and Validation Accuracy Graph#

# %%
acc = classifier.history['accuracy']
val_acc = classifier.history['val_accuracy']
loss = classifier.history['loss']
val_loss = classifier.history['val_loss']
epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.ylabel('accuracy') 
plt.xlabel('epoch')
plt.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# #Training and Validation Loss Graph#

# %%
acc = classifier.history['accuracy']
val_acc = classifier.history['val_accuracy']
loss = classifier.history['loss']
val_loss = classifier.history['val_loss']
epochs = range(len(acc))

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.ylabel('loss') 
plt.xlabel('epoch')
plt.legend()
plt.show()

# %% [markdown]
# #Final Prediction#

# %%
fig = plt.figure(figsize=(18, 10))

rows = 1
columns = 3

fig.add_subplot(rows, columns, 1)
ImagePath = '/content/COVID-19 Radiography Database/validation/covid/COVID-19 (193).png'
Image = cv2.imread(ImagePath)
test_image = image.load_img(ImagePath,target_size=(512, 512))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image,axis=0)
result = cnn.predict(test_image)

plt.imshow(Image)
col = 'green' if labels[0] == labels[np.argmax(result)] else 'red'
plt.xlabel(labels[0])
plt.ylabel(labels[np.argmax(result)], color=col)

fig.add_subplot(rows, columns, 2)

ImagePath = '/content/COVID-19 Radiography Database/validation/normal/NORMAL (118).png'
test_image = image.load_img(ImagePath,target_size=(512, 512))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image,axis=0)
result = cnn.predict(test_image)
Image = cv2.imread(ImagePath)

plt.imshow(Image)
col = 'green' if labels[1] == labels[np.argmax(result)] else 'red'
plt.xlabel(labels[1])
plt.ylabel(labels[np.argmax(result)], color=col)

fig.add_subplot(rows, columns, 3)
ImagePath = '/content/COVID-19 Radiography Database/validation/viral/Viral Pneumonia (251).png'
Image = cv2.imread(ImagePath)
test_image = image.load_img(ImagePath,target_size=(512, 512))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image,axis=0)
result = cnn.predict(test_image)

plt.imshow(Image)
col = 'green' if labels[2] == labels[np.argmax(result)] else 'red'
plt.xlabel(labels[2])
plt.ylabel(labels[np.argmax(result)], color=col)
# Out:
# Text(0, 0.5, 'viral')

# %% [markdown]
# ##Confusion Matrix##

# %%
def plot_confusion_matrix(cm, classes, normalize = True, title = 'Confusion matrix', cmap = plt.cm.Reds):
    plt.figure(figsize = (10,6))
    plt.imshow(cm, interpolation = 'nearest', cmap = cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 45, fontsize = 10)
    plt.yticks(tick_marks, classes, fontsize = 10)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis = 1)[:, np.newaxis]
        cm = np.around(cm, decimals = 2)
        cm[np.isnan(cm)] = 0.0
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment = "center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True Label', fontsize = 13)
    plt.xlabel('Predicted Label', fontsize = 13)

# %%
target_names = ['covid', 'normal', 'viral']

Y_pred = cnn.predict(test_set)
y_pred = np.argmax(Y_pred, axis=1)

# %%
print('Confusion Matrix')
cm = confusion_matrix(test_set.classes, y_pred)
plot_confusion_matrix(cm, target_names, title = 'Confusion Matrix')
# Out:
# Confusion Matrix
# Normalized confusion matrix

# %%
print('                      Classification Report')
print()
print(classification_report(test_set.classes, y_pred, target_names = target_names))
# Out:
#                       Classification Report
#
#               precision    recall  f1-score   support
#
#        covid       0.00      0.00      0.00       315
#       normal       0.00      0.00      0.00       315
#        viral       0.33      1.00      0.50       315
#
#     accuracy                           0.33       945
#    macro avg       0.11      0.33      0.17       945
# weighted avg       0.11      0.33      0.17       945
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
