# %% [markdown]
# <a href="https://colab.research.google.com/github/prince90038/corona-prediction/blob/main/Experiment512_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Covid-19 Classification Based On Chest X-Ray#

# %% [markdown]
# Mount the Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Unzip the Dataset File

# %%
from zipfile import ZipFile
file_name = "/content/drive/MyDrive/COVID-19 Radiography Database.zip"

with ZipFile(file_name,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %% [markdown]
# Importing the Libraries

# %%
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPool2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Activation
from keras.preprocessing.image import ImageDataGenerator
import time
import matplotlib.pyplot as plt
import numpy as np
from keras.preprocessing import image
import cv2
import os
import random
import shutil
from sklearn.metrics import confusion_matrix
import seaborn as sns
import itertools
from sklearn.metrics import classification_report

# %% [markdown]
# #Creating Custom Dataset#

# %%
class_names = ['normal', 'viral', 'covid']
root_dir = 'COVID-19 Radiography Database'
source_dirs = ['NORMAL', 'Viral Pneumonia', 'COVID-19']

if os.path.isdir(os.path.join(root_dir, source_dirs[1])):
    os.mkdir(os.path.join(root_dir, 'test'))
    os.mkdir(os.path.join(root_dir, 'train'))
    os.mkdir(os.path.join(root_dir,'validation'))

    for i, d in enumerate(source_dirs):
        os.rename(os.path.join(root_dir, d), os.path.join(root_dir, class_names[i]))

    for c in class_names:
        os.mkdir(os.path.join(root_dir, 'test', c))
        os.mkdir(os.path.join(root_dir, 'validation', c))

    for c in class_names:
        images = [x for x in os.listdir(os.path.join(root_dir, c)) if x.lower().endswith('png')]
        selected_images = random.sample(images, 315)
        for image in selected_images:
            source_path = os.path.join(root_dir, c, image)
            target_path = os.path.join(root_dir, 'test', c, image)
            shutil.move(source_path, target_path)
    for c in class_names:
        images = [x for x in os.listdir(os.path.join(root_dir, c)) if x.lower().endswith('png')]
        selected_images = random.sample(images, 10)
        for image in selected_images:
            source_path = os.path.join(root_dir, c, image)
            target_path = os.path.join(root_dir, 'validation', c, image)
            shutil.move(source_path, target_path)     


     
    for c in class_names:
        shutil.move(os.path.join(root_dir, c), os.path.join(root_dir, 'train'))

# %% [markdown]
# #Data Pre-processing Phase#

# %%
TrainingImagePath='/content/COVID-19 Radiography Database/train'
TestImagePath='/content/COVID-19 Radiography Database/test'
batch_size = 32

train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range = 0.1,
        zoom_range = 0.1,
        horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory(
        TrainingImagePath,
        target_size = (512, 512),
        batch_size = batch_size,
        class_mode = 'categorical')

test_set = test_datagen.flow_from_directory(
        TestImagePath,
        target_size = (512, 512),
        batch_size = batch_size,
        shuffle = False,
        class_mode = 'categorical')

test_set.class_indices
# Out:
# Found 2854 images belonging to 3 classes.
# Found 945 images belonging to 3 classes.
# {'covid': 0, 'normal': 1, 'viral': 2}

# %%
TrainClasses = training_set.class_indices

labels = {}
for faceName, faceValue in TrainClasses.items():
    labels[faceValue] = faceName

print('Mapping of Dataset\n')
for key, value in labels.items():
    print(str(key) + " --> " + value)

OutputNeurons = len(labels)
print('\nRequired Output Neurons:{}'.format(OutputNeurons))
# Out:
# Mapping of Dataset
#
# 0 --> covid
# 1 --> normal
# 2 --> viral
#
# Required Output Neurons:3

# %% [markdown]
# #CNN Model#

# %% [markdown]
# Initializing the Convolutional Neural Network

# %%
cnn = Sequential()

# %% [markdown]
# #Step:1#
#
# #Convolution#

# %% [markdown]
# Adding the first layer of CNN

# %%
cnn.add(Convolution2D(32, kernel_size=(5, 5), strides=(1, 1), input_shape=(512,512,3), activation='relu'))

# %% [markdown]
# #Step:2#
# #MAX Pooling#

# %%
cnn.add(MaxPool2D(pool_size=(2,2)))

# %% [markdown]
# #Addtional Layer of Convulution#

# %%
cnn.add(Convolution2D(64, kernel_size=(5, 5), strides=(1, 1), activation='relu'))
cnn.add(MaxPool2D(pool_size=(2,2)))

# %%
cnn.add(Convolution2D(128, kernel_size=(5, 5), strides=(1, 1), activation='relu'))
cnn.add(MaxPool2D(pool_size=(2,2)))

# %%
cnn.add(Convolution2D(512, kernel_size=(5, 5), strides=(1, 1), activation='relu'))
cnn.add(MaxPool2D(pool_size=(2,2)))

# %% [markdown]
# #Step:3#
# #Flattening#

# %%
cnn.add(Flatten())

# %% [markdown]
# #Step:4#
# #Fully Connected Neural Network#

# %%
cnn.add(Dense(200, activation='relu'))
cnn.add(Dropout(0.3))
cnn.add(Dense(100, activation='relu'))
cnn.add(Dropout(0.3))
cnn.add(Dense(50, activation='relu'))
cnn.add(Dropout(0.3))
cnn.add(Dense(OutputNeurons, activation='softmax'))

# %% [markdown]
# #Compiling the CNN#

# %%
cnn.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=["accuracy"])

# %% [markdown]
# #Start Training the Model#

# %%
StartTime=time.time()
classifier = cnn.fit(
                    training_set,
                    # steps_per_epoch=160,
                    epochs=50,
                    validation_data=test_set,
                    validation_steps=(765//batch_size))

EndTime = time.time()
print()
print("*"*137)
print('Total Time Taken to Train the Model: ', round((EndTime-StartTime)/60), 'Minutes')
# Out:
# Epoch 1/50
# 90/90 [==============================] - 235s 2s/step - loss: 1.4294 - accuracy: 0.4063 - val_loss: 0.8994 - val_accuracy: 0.6753
# Epoch 2/50
# 90/90 [==============================] - 188s 2s/step - loss: 0.8092 - accuracy: 0.6145 - val_loss: 0.3199 - val_accuracy: 0.8899
# Epoch 3/50
# 90/90 [==============================] - 195s 2s/step - loss: 0.5084 - accuracy: 0.8016 - val_loss: 0.3208 - val_accuracy: 0.8913
# Epoch 4/50
# 90/90 [==============================] - 196s 2s/step - loss: 0.4747 - accuracy: 0.8355 - val_loss: 0.2416 - val_accuracy: 0.9130
# Epoch 5/50
# 90/90 [==============================] - 197s 2s/step - loss: 0.3701 - accuracy: 0.8743 - val_loss: 0.1894 - val_accuracy: 0.9307
# Epoch 6/50
# 90/90 [==============================] - 196s 2s/step - loss: 0.3335 - accuracy: 0.8802 - val_loss: 0.1590 - val_accuracy: 0.9524
# Epoch 7/50
# 90/90 [==============================] - 196s 2s/step - loss: 0.3365 - accuracy: 0.8893 - val_loss: 0.1675 - val_accuracy: 0.9389
# Epoch 8/50
# 90/90 [==============================] - 196s 2s/step - loss: 0.2851 - accuracy: 0.9106 - val_loss: 0.1702 - val_accuracy: 0.9457
# Epoch 9/50
# 90/90 [==============================] - 195s 2s/step - loss: 0.2844 - accuracy: 0.9082 - val_loss: 0.1563 - val_accuracy: 0.9457
# Epoch 10/50
# 90/90 [==============================] - 196s 2s/step - loss: 0.2667 - accuracy: 0.9006 - val_loss: 0.1363 - val_accuracy: 0.9538
# Epoch 11/50
# 90/90 [==============================] - 195s 2s/step - loss: 0.2556 - accuracy: 0.9107 - val_loss: 0.1432 - val_accuracy: 0.9524
# Epoch 12/50
# 90/90 [==============================] - 195s 2s/step - loss: 0.2192 - accuracy: 0.9342 - val_loss: 0.1135 - val_accuracy: 0.9579
# Epoch 13/50
# 90/90 [==============================] - 192s 2s/step - loss: 0.2253 - accuracy: 0.9232 - val_loss: 0.1302 - val_accuracy: 0.9579
# Epoch 14/50
# 90/90 [==============================] - 192s 2s/step - loss: 0.2282 - accuracy: 0.9283 - val_loss: 0.1544 - val_accuracy: 0.9552
# Epoch 15/50
# 90/90 [==============================] - 191s 2s/step - loss: 0.2374 - accuracy: 0.9098 - val_loss: 0.1234 - val_accuracy: 0.9538
# Epoch 16/50
# 90/90 [==============================] - 185s 2s/step - loss: 0.3314 - accuracy: 0.8879 - val_loss: 0.1859 - val_accuracy: 0.9524
# Epoch 17/50
# 90/90 [==============================] - 190s 2s/step - loss: 0.2532 - accuracy: 0.9189 - val_loss: 0.1203 - val_accuracy: 0.9538
# Epoch 18/50
# 90/90 [==============================] - 191s 2s/step - loss: 0.2102 - accuracy: 0.9339 - val_loss: 0.1189 - val_accuracy: 0.9633
# Epoch 19/50
# 90/90 [==============================] - 192s 2s/step - loss: 0.1878 - accuracy: 0.9364 - val_loss: 0.1277 - val_accuracy: 0.9606
# Epoch 20/50
# 90/90 [==============================] - 191s 2s/step - loss: 0.1983 - accuracy: 0.9338 - val_loss: 0.1050 - val_accuracy: 0.9620
# Epoch 21/50
# 90/90 [==============================] - 194s 2s/step - loss: 0.1952 - accuracy: 0.9342 - val_loss: 0.1245 - val_accuracy: 0.9606
# Epoch 22/50
# 90/90 [==============================] - 194s 2s/step - loss: 0.1607 - accuracy: 0.9473 - val_loss: 0.1469 - val_accuracy: 0.9429
# Epoch 23/50
# 90/90 [==============================] - 193s 2s/step - loss: 0.2506 - accuracy: 0.9426 - val_loss: 0.6868 - val_accuracy: 0.8003
# Epoch 24/50
# 90/90 [==============================] - 196s 2s/step - loss: 0.4754 - accuracy: 0.8548 - val_loss: 0.1695 - val_accuracy: 0.9592
# Epoch 25/50
# 90/90 [==============================] - 201s 2s/step - loss: 0.2508 - accuracy: 0.9182 - val_loss: 0.1478 - val_accuracy: 0.9579
# Epoch 26/50
# 90/90 [==============================] - 205s 2s/step - loss: 0.2452 - accuracy: 0.9230 - val_loss: 0.1517 - val_accuracy: 0.9457
# Epoch 27/50
# 90/90 [==============================] - 205s 2s/step - loss: 0.2312 - accuracy: 0.9258 - val_loss: 0.1272 - val_accuracy: 0.9647
# Epoch 28/50
# 90/90 [==============================] - 204s 2s/step - loss: 0.1934 - accuracy: 0.9388 - val_loss: 0.1237 - val_accuracy: 0.9633
# Epoch 29/50
# 90/90 [==============================] - 201s 2s/step - loss: 0.1801 - accuracy: 0.9399 - val_loss: 0.1317 - val_accuracy: 0.9592
# Epoch 30/50
# 90/90 [==============================] - 204s 2s/step - loss: 0.1936 - accuracy: 0.9328 - val_loss: 0.1207 - val_accuracy: 0.9592
# Epoch 31/50
# 90/90 [==============================] - 209s 2s/step - loss: 0.1639 - accuracy: 0.9427 - val_loss: 0.1181 - val_accuracy: 0.9647
# Epoch 32/50
# 90/90 [==============================] - 208s 2s/step - loss: 0.1657 - accuracy: 0.9445 - val_loss: 0.1216 - val_accuracy: 0.9620
# Epoch 33/50
# 90/90 [==============================] - 209s 2s/step - loss: 0.2719 - accuracy: 0.9324 - val_loss: 0.8646 - val_accuracy: 0.7011
# Epoch 34/50
# 90/90 [==============================] - 209s 2s/step - loss: 0.5741 - accuracy: 0.8136 - val_loss: 0.2145 - val_accuracy: 0.9389
# Epoch 35/50
# 90/90 [==============================] - 209s 2s/step - loss: 0.2678 - accuracy: 0.9164 - val_loss: 0.2945 - val_accuracy: 0.9470
# Epoch 36/50
# 90/90 [==============================] - 210s 2s/step - loss: 0.2489 - accuracy: 0.9143 - val_loss: 0.3531 - val_accuracy: 0.9497
# Epoch 37/50
# 90/90 [==============================] - 210s 2s/step - loss: 0.2242 - accuracy: 0.9291 - val_loss: 0.1409 - val_accuracy: 0.9524
# Epoch 38/50
# 90/90 [==============================] - 209s 2s/step - loss: 0.1882 - accuracy: 0.9361 - val_loss: 0.2514 - val_accuracy: 0.9457
# Epoch 39/50
# 90/90 [==============================] - 209s 2s/step - loss: 0.2067 - accuracy: 0.9313 - val_loss: 0.1237 - val_accuracy: 0.9592
# Epoch 40/50
# 90/90 [==============================] - 209s 2s/step - loss: 0.1719 - accuracy: 0.9423 - val_loss: 0.1603 - val_accuracy: 0.9606
# Epoch 41/50
# 90/90 [==============================] - 208s 2s/step - loss: 0.1843 - accuracy: 0.9425 - val_loss: 0.1793 - val_accuracy: 0.9457
# Epoch 42/50
# 90/90 [==============================] - 208s 2s/step - loss: 0.1491 - accuracy: 0.9471 - val_loss: 0.1525 - val_accuracy: 0.9620
# Epoch 43/50
# 90/90 [==============================] - 208s 2s/step - loss: 0.2067 - accuracy: 0.9409 - val_loss: 0.1954 - val_accuracy: 0.9402
# Epoch 44/50
# 90/90 [==============================] - 208s 2s/step - loss: 0.1610 - accuracy: 0.9502 - val_loss: 0.1610 - val_accuracy: 0.9538
# Epoch 45/50
# 90/90 [==============================] - 209s 2s/step - loss: 0.1725 - accuracy: 0.9410 - val_loss: 0.1434 - val_accuracy: 0.9579
# Epoch 46/50
# 90/90 [==============================] - 208s 2s/step - loss: 0.1685 - accuracy: 0.9348 - val_loss: 0.1365 - val_accuracy: 0.9620
# Epoch 47/50
# 90/90 [==============================] - 208s 2s/step - loss: 0.1658 - accuracy: 0.9420 - val_loss: 0.1152 - val_accuracy: 0.9688
# Epoch 48/50
# 90/90 [==============================] - 207s 2s/step - loss: 0.1541 - accuracy: 0.9529 - val_loss: 0.1250 - val_accuracy: 0.9633
# Epoch 49/50
# 90/90 [==============================] - 207s 2s/step - loss: 0.1522 - accuracy: 0.9480 - val_loss: 0.1210 - val_accuracy: 0.9633
# Epoch 50/50
# 90/90 [==============================] - 207s 2s/step - loss: 0.1511 - accuracy: 0.9503 - val_loss: 0.1355 - val_accuracy: 0.9647
#
# *****************************************************************************************************************************************
# Total Time Taken to Train the Model:  170 Minutes

# %% [markdown]
# #Training and Validation Accuracy Graph#

# %%
acc = classifier.history['accuracy']
val_acc = classifier.history['val_accuracy']
loss = classifier.history['loss']
val_loss = classifier.history['val_loss']
epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.ylabel('accuracy') 
plt.xlabel('epoch')
plt.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# #Training and Validation Loss Graph#

# %%
acc = classifier.history['accuracy']
val_acc = classifier.history['val_accuracy']
loss = classifier.history['loss']
val_loss = classifier.history['val_loss']
epochs = range(len(acc))

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.ylabel('loss') 
plt.xlabel('epoch')
plt.legend()
plt.show()

# %% [markdown]
# #Final Prediction#

# %%
fig = plt.figure(figsize=(18, 10))

rows = 1
columns = 3

fig.add_subplot(rows, columns, 1)
ImagePath = '/content/COVID-19 Radiography Database/validation/covid/COVID-19 (1005).png'
Image = cv2.imread(ImagePath)
test_image = image.load_img(ImagePath,target_size=(512, 512))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image,axis=0)
result = cnn.predict(test_image)

plt.imshow(Image)
col = 'green' if labels[0] == labels[np.argmax(result)] else 'red'
plt.xlabel(labels[0])
plt.ylabel(labels[np.argmax(result)], color=col)

fig.add_subplot(rows, columns, 2)

ImagePath = '/content/COVID-19 Radiography Database/validation/normal/NORMAL (1002).png'
test_image = image.load_img(ImagePath,target_size=(512, 512))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image,axis=0)
result = cnn.predict(test_image)
Image = cv2.imread(ImagePath)

plt.imshow(Image)
col = 'green' if labels[1] == labels[np.argmax(result)] else 'red'
plt.xlabel(labels[1])
plt.ylabel(labels[np.argmax(result)], color=col)

fig.add_subplot(rows, columns, 3)
ImagePath = '/content/COVID-19 Radiography Database/validation/viral/Viral Pneumonia (263).png'
Image = cv2.imread(ImagePath)
test_image = image.load_img(ImagePath,target_size=(512, 512))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image,axis=0)
result = cnn.predict(test_image)

plt.imshow(Image)
col = 'green' if labels[2] == labels[np.argmax(result)] else 'red'
plt.xlabel(labels[2])
plt.ylabel(labels[np.argmax(result)], color=col)
# Out:
# Text(0, 0.5, 'viral')

# %% [markdown]
# ##Confusion Matrix##

# %%
def plot_confusion_matrix(cm, classes, normalize = True, title = 'Confusion matrix', cmap = plt.cm.Reds):
    plt.figure(figsize = (10,6))
    plt.imshow(cm, interpolation = 'nearest', cmap = cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 45, fontsize = 10)
    plt.yticks(tick_marks, classes, fontsize = 10)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis = 1)[:, np.newaxis]
        cm = np.around(cm, decimals = 2)
        cm[np.isnan(cm)] = 0.0
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment = "center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True Label', fontsize = 13)
    plt.xlabel('Predicted Label', fontsize = 13)

# %%
target_names = ['covid', 'normal', 'viral']

Y_pred = cnn.predict(test_set)
y_pred = np.argmax(Y_pred, axis=1)

# %%
print('Confusion Matrix')
cm = confusion_matrix(test_set.classes, y_pred)
plot_confusion_matrix(cm, target_names, title = 'Confusion Matrix')
# Out:
# Confusion Matrix
# Normalized confusion matrix

# %%
print('                      Classification Report')
print()
print(classification_report(test_set.classes, y_pred, target_names = target_names))
# Out:
#                       Classification Report
#
#               precision    recall  f1-score   support
#
#        covid       0.99      0.97      0.98       315
#       normal       0.94      0.97      0.95       315
#        viral       0.94      0.94      0.94       315
#
#     accuracy                           0.96       945
#    macro avg       0.96      0.96      0.96       945
# weighted avg       0.96      0.96      0.96       945
